# %% [markdown]
# ### Intro to Linked Lists

# %%
class Node:
    #//-----------Setting the last node to always NONE---------------------//
    def __init__(self,data):
        self.data = data
        self.next = None
        
class Linked_List:
    #//--------Since there is no LList , the head is also set to NONE------------//
    def __init__(self):
        self.head = None
        
    def printer_LL(self):
        temp = self.head
        
        while(temp):
            print(temp.data, end=" ")
            temp = temp.next

if __name__ == '__main__' :
    
    LList  = Linked_List()
    
    #// ----Here simply we have created three nodes and then combined them altogether------//
    LList.head = Node(1)   #//-----------Here first we decide head Node----------//
    second = Node(2)
    third = Node(3)
    
    LList.head.next = second
    second.next = third
    
    
    LList.printer_LL()
# Out:
# 1 2 3

# %% [markdown]
# #### Inserting Nodes to a LL

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
class Linked_List:

    def __init__(self):
        self.head = None
    
    #//-------------Below theree functions are to insert data in the Linked List-------------//
    
    # 1. This one is to insert data at the beginning of the Linked List-----//
    def Push_bg(self, new_data):
        
        new_node = Node(new_data)
        new_node.next = self.head
        self.head = new_node
    
        
    #2.  This one is to insert the data at anywhere in between the HEAD and NEXT-----//
    def Push_mid(self, prev_node, new_data):
        
        if prev_node is None:
            print ("The given previous node must inLinkedList.")
            return None
        
        new_node = Node(new_data)
        new_node.next = self.prev_node
        self.prev_node = new_node
        
        
    #3. This one is to insert the data at the end of the LList-------------//
    def Push_end(self, new_data):
        
        new_node = Node(new_data)
        
        if self.head is None:    #// ---This is useful if the LList is empty --------------//
            self.head = new_node
            return
        
        last = self.head
        
        while (last.next):  #//--------It will traverse the list until it reaches to end, of it means
            last = last.next            # that till the node value become NONE.
        
        last.next = new_node
        

    def printer_LL(self):
        temp = self.head
        
        while(temp):
            print(temp.data, end=" ")
            temp = temp.next

if __name__ == '__main__' :

    LList  = Linked_List()

    LList.head = Node(1)
    second = Node(2)
    third = Node(3)
    
    LList.head.next = second
    second.next = third
    
    LList.Push_bg(44)
    LList.Push_bg(45)
    LList.printer_LL()
# Out:
# 45 44 1 2 3

# %% [markdown]
# #### Deleting Nodes from a LL

# %% [markdown]
# ###### Iterative Approach

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
class Linked_List:

    def __init__(self):
        self.head = None
    
    #//-------------Below theree functions are to insert data in the Linked List-------------//
    
    # 1. This one is to insert data at the beginning of the Linked List-----//
    def Push_bg(self, new_data):
        
        new_node = Node(new_data)
        new_node.next = self.head
        self.head = new_node
    
        
    #2.  This one is to insert the data at anywhere in between the HEAD and NEXT-----//
    def Push_mid(self, prev_node, new_data):
        
        if prev_node is None:
            print ("The given previous node must inLinkedList.")
            return None
        
        new_node = Node(new_data)
        new_node.next = self.prev_node
        self.prev_node = new_node
        
        
    #3. This one is to insert the data at the end of the LList-------------//
    def Push_end(self, new_data):
        
        new_node = Node(new_data)
        
        if self.head is None:    #// ---This is useful if the LList is empty --------------//
            self.head = new_node
            return
        
        last = self.head
        
        while (last.next):  #//--------It will traverse the list until it reaches to end, of it means
            last = last.next            # that till the node value become NONE.
        
        last.next = new_node
        
    def delete_itr(self, key):
        temp = self.head
    
        if (temp is not None):
            if (temp.data == key):
                self.head = temp.next
                temp = None
                return

        while (temp is not None):            
            if temp.data == key:
                break
        
            prev = temp
            temp = temp.next
                
        if temp == None:
            return
        
        prev.next = temp.next
        temp = None
        
        
    def printer_LL(self):
        temp = self.head
        
        while(temp):
            print(temp.data, end=" ")
            temp = temp.next

if __name__ == '__main__' :
    LList  = Linked_List()

    LList.head = Node(1)
    second = Node(2)
    third = Node(3)
    
    LList.head.next = second
    second.next = third
    
    print("Original List : ")
    LList.printer_LL()
    print("\n")
    LList.Push_bg(44)
    LList.Push_end(46)
    print("List after pushing elemenets : ")
    LList.printer_LL()
    print("\n")
    LList.delete_itr(44)
    print("List after deleting element : ")
    LList.printer_LL()
# Out:
# Original List :
# 1 2 3
#
# List after pushing elemenets :
# 44 1 2 3 46
#
# List after deleting element :
# 1 2 3 46

# %% [markdown]
# ###### Recursive Approach

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
class Linked_List:

    def __init__(self):
        self.head = None
    
    #//-------------Below theree functions are to insert data in the Linked List-------------//
    
    # 1. This one is to insert data at the beginning of the Linked List-----//
    def Push_bg(self, new_data):
        
        new_node = Node(new_data)
        new_node.next = self.head
        self.head = new_node
    
        
    #2.  This one is to insert the data at anywhere in between the HEAD and NEXT-----//
    def Push_mid(self, prev_node, new_data):
        
        if prev_node is None:
            print ("The given previous node must inLinkedList.")
            return None
        
        new_node = Node(new_data)
        new_node.next = self.prev_node
        self.prev_node = new_node
        
        
    #3. This one is to insert the data at the end of the LList-------------//
    def Push_end(self, new_data):
        
        new_node = Node(new_data)
        
        if self.head is None:    #// ---This is useful if the LList is empty --------------//
            self.head = new_node
            return
        
        last = self.head
        
        while (last.next):  #//--------It will traverse the list until it reaches to end, of it means
            last = last.next            # that till the node value become NONE.
        
        last.next = new_node
        
        
    def delete_Rec(self,key):
        
        
    

    def printer_LL(self):
        temp = self.head
        
        while(temp):
            print(temp.data, end=" ")
            temp = temp.next

if __name__ == '__main__' :

    LList  = Linked_List()

    LList.head = Node(1)
    second = Node(2)
    third = Node(3)
    
    LList.head.next = second
    second.next = third
    
    LList.Push_bg(44)
    LList.Push_bg(45)
    LList.printer_LL()
# Out:
#   File "<ipython-input-4-2a024c83c90b>", line 55
#     def printer_LL(self):
#     ^
# IndentationError: expected an indented block

# %% [markdown]
# #### Deleting a Node from a given Position

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
class Linked_List:

    def __init__(self):
        self.head = None
    
    #//-------------Below theree functions are to insert data in the Linked List-------------//
    
    # 1. This one is to insert data at the beginning of the Linked List-----//
    def Push_bg(self, new_data):
        
        new_node = Node(new_data)
        new_node.next = self.head
        self.head = new_node
    
        
    #2.  This one is to insert the data at anywhere in between the HEAD and NEXT-----//
    def Push_mid(self, prev_node, new_data):
        
        if prev_node is None:
            print ("The given previous node must inLinkedList.")
            return None
        
        new_node = Node(new_data)
        new_node.next = self.prev_node
        self.prev_node = new_node
        
        
    #3. This one is to insert the data at the end of the ListL-------------//
    def Push_end(self, new_data):
        
        new_node = Node(new_data)
        
        if self.head is None:    #// ---This is useful if the ListL is empty --------------//
            self.head = new_node
            return
        
        last = self.head
        
        while (last.next):  #//--------It will traverse the list until it reaches to end, of it means
            last = last.next            # that till the node value become NONE.
        
        last.next = new_node
        
    def delete_pos(self, pos):
        
        if self.head == None:
            return
        
        temp = self.head
        
        if pos == 0:
            self.head = temp.next
            temp = None
            return
        
        #//---------findind the node to be deleted-------------/
        
        for i in range(pos-1):
            temp = temp.next
            if temp is None:
                return
            
        if (temp is None):
            return
            
        if (temp.next is None):
            return
        
        next = temp.next.next
        temp.next = None
        temp.next = next   #//Removing this line will delete all nodes after the given position
        
        
    def printer_LL(self):
        temp = self.head
        
        while(temp):
            print(temp.data, end=" ")
            temp = temp.next

            
position = 3
            
if __name__ == '__main__' :
    ListL  = Linked_List()

    ListL.head = Node(1)
    second = Node(2)
    third = Node(3)
    
    ListL.head.next = second
    second.next = third
    
    print("Original List : ")
    ListL.printer_LL()
    print("\n")
    ListL.Push_bg(44)
    ListL.Push_bg(23)
    ListL.Push_bg(14)
    ListL.Push_bg(94)
    ListL.Push_end(46)
    print("List after pushing elemenets : ")
    ListL.printer_LL()
    print("\n")
    ListL.delete_pos(5)    #you can consider the position as index value as in arrays
    print("List after deleting element from given position: ")
    ListL.printer_LL()

# %% [markdown]
# #### Write a function to delete a Linked List

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
class Linked_List:

    def __init__(self):
        self.head = None
    
    #//-------------Below theree functions are to insert data in the Linked List-------------//
    
    # 1. This one is to insert data at the beginning of the Linked List-----//
    def Push_bg(self, new_data):
        
        new_node = Node(new_data)
        new_node.next = self.head
        self.head = new_node
    
        
    #2.  This one is to insert the data at anywhere in between the HEAD and NEXT-----//
    def Push_mid(self, prev_node, new_data):
        
        if prev_node is None:
            print ("The given previous node must inLinkedList.")
            return None
        
        new_node = Node(new_data)
        new_node.next = self.prev_node
        self.prev_node = new_node
        
        
    #3. This one is to insert the data at the end of the ListL-------------//
    def Push_end(self, new_data):
        
        new_node = Node(new_data)
        
        if self.head is None:    #// ---This is useful if the ListL is empty --------------//
            self.head = new_node
            return
        
        last = self.head
        
        while (last.next):  #//--------It will traverse the list until it reaches to end, of it means
            last = last.next            # that till the node value become NONE.
        
        last.next = new_node
        
    def delete_LL(self):
        
        if self.head == None:
            return
        
        temp = self.head
        
        while temp:
            prev = temp.next
            del temp.data
            temp = prev
            
        print("Linked List is Deleted")

    def printer_LL(self):
        temp = self.head
        
        while(temp):
            print(temp.data, end=" ")
            temp = temp.next

            
position = 3
            
if __name__ == '__main__' :
    ListL  = Linked_List()

    ListL.head = Node(1)
    second = Node(2)
    third = Node(3)
    
    ListL.head.next = second
    second.next = third
    
    print("Original List : ")
    ListL.printer_LL()
    print("\n")
    ListL.Push_bg(44)
    ListL.Push_bg(23)
    ListL.Push_bg(14)
    print("List after pushing elemenets : ")
    ListL.printer_LL()
    print("\n")
    ListL.delete_LL()

# %% [markdown]
# #### Find Length of a Linked List (Iterative and Recursive)

# %% [markdown]
# ###### ITERATIVE APPROACH

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
class Linked_List:

    def __init__(self):
        self.head = None
        
    def Push(self, new_data):
        
        new_node = Node(new_data)
        new_node.next = self.head
        self.head = new_node

    def printer_LL(self):
        temp = self.head
        
        while(temp):
            print(temp.data, end=" ")
            temp = temp.next
            
    def FindLength_itr(self):
        
        count = 0
        temp = self.head
        while temp is not None:
            temp = temp.next
            count += 1
        print("\n")
        print("The length of the list is : ", count)

            
if __name__ == '__main__' :
    ListL  = Linked_List()

    ListL.head = Node(1)
    second = Node(2)
    third = Node(3)
    
    ListL.head.next = second
    second.next = third
    
    print("Original List : ")
    ListL.printer_LL()
    print("\n")
    ListL.Push(44)
    ListL.Push(23)
    ListL.Push(14)
    ListL.Push(44)
    print("After Pushing elements : ")
    ListL.printer_LL()
   
    ListL.FindLength_itr()

# %% [markdown]
# #### RECURSIVE APPROACH

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
class Linked_List:

    def __init__(self):
        self.head = None
        
    def Push(self, new_data):
        
        new_node = Node(new_data)
        new_node.next = self.head
        self.head = new_node

    def printer_LL(self):
        temp = self.head
        
        while(temp):
            print(temp.data, end=" ")
            temp = temp.next
           
    def getcount(self, node):
        
        if (not node):
            return 0
        
        else:
            return 1+ self.getcount(node.next)
    
    def FindLength_rec(self):
        return print("The length of the list is : ",self.getcount(self.head))
    
    

            
if __name__ == '__main__' :
    ListL  = Linked_List()

    ListL.head = Node(1)
    second = Node(2)
    third = Node(3)
    
    ListL.head.next = second
    second.next = third
    
    print("Original List : ")
    ListL.printer_LL()
    print("\n")
    ListL.Push(44)
    ListL.Push(23)
    ListL.Push(14)
    ListL.Push(44)
    print("After Pushing elements : ")
    ListL.printer_LL()
    print("\n")
    ListL.FindLength_rec()

# %% [markdown]
# #### Search an element in a Linked List (Iterative and Recursive)

# %% [markdown]
# ###### ITERATIVE APPROACH

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
class Linked_List:

    def __init__(self):
        self.head = None
        
    def Push(self, new_data):
        
        new_node = Node(new_data)
        new_node.next = self.head
        self.head = new_node

    def printer_LL(self):
        temp = self.head
        
        while(temp):
            print(temp.data, end=" ")
            temp = temp.next
           
    def Searching_itr(self,val):
        
        if self.head is None:
            return 
        
        temp =  self.head
        
        while (temp):
            if temp.data == val:
                return print("yes")
            temp = temp.next
                
        return print("Not found")    
                
if __name__ == '__main__' :
    ListL  = Linked_List()

    ListL.head = Node(1)
    second = Node(2)
    third = Node(3)
    
    ListL.head.next = second
    second.next = third
    
    print("Original List : ")
    ListL.printer_LL()
    print("\n")
    ListL.Push(44)
    ListL.Push(23)
    ListL.Push(14)
    ListL.Push(44)
    print("After Pushing elements : ")
    ListL.printer_LL()
    print("\n")
    ListL.Searching_itr(3)

# %% [markdown]
# ###### RECURSIVE APPROACH

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
class Linked_List:

    def __init__(self):
        self.head = None
        
    def Push(self, new_data):
        
        new_node = Node(new_data)
        new_node.next = self.head
        self.head = new_node

    def printer_LL(self):
        temp = self.head
        
        while(temp):
            print(temp.data, end=" ")
            temp = temp.next
           
    def Searching(self, node , val):
        
        if (not node):
            return 0
        
        if node.data == val:
            return True
        
        else:
            return self.Searching(node.next , val)
    
    def Searching_rec(self, val):
        return self.Searching(self.head , val)
    
    

            
if __name__ == '__main__' :
    ListL  = Linked_List()

    ListL.head = Node(1)
    second = Node(2)
    third = Node(3)
    
    ListL.head.next = second
    second.next = third
    
    print("Original List : ")
    ListL.printer_LL()
    print("\n")
    ListL.Push(44)
    ListL.Push(23)
    ListL.Push(14)
    ListL.Push(44)
    print("After Pushing elements : ")
    ListL.printer_LL()
    print("\n")
    if ListL.Searching_rec(44):
        print("Yes")
    else:
        print("Not Found")

# %% [markdown]
# #### Write a function to get Nth node in a Linked List

# %% [markdown]
# ###### ITERATIVE APPROACH

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
class Linked_List:

    def __init__(self):
        self.head = None
        
    def Push(self, new_data):
        
        new_node = Node(new_data)
        new_node.next = self.head
        self.head = new_node

    def printer_LL(self):
        temp = self.head
        
        while(temp):
            print(temp.data, end=" ")
            temp = temp.next
           
    def Nth_Node_itr(self,N):
        
        if self.head is None:
            return 0
        
        temp = self.head
        for i in range(N-1):
            temp = temp.next
            
            if i == N-2:
                print(temp.data)
                
if __name__ == '__main__' :
    ListL  = Linked_List()

    ListL.head = Node(1)
    second = Node(2)
    third = Node(3)
    
    ListL.head.next = second
    second.next = third
    
    print("Original List : ")
    ListL.printer_LL()
    print("\n")
    ListL.Push(44)
    ListL.Push(23)
    ListL.Push(14)
    ListL.Push(44)
    print("After Pushing elements : ")
    ListL.printer_LL()
    print("\n")
    ListL.Nth_Node_itr(4)

# %% [markdown]
# ###### RECURSIVE APPROACH

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
class Linked_List:

    def __init__(self):
        self.head = None
        
    def Push(self, new_data):
        
        new_node = Node(new_data)
        new_node.next = self.head
        self.head = new_node

    def printer_LL(self):
        temp = self.head
        
        while(temp):
            print(temp.data, end=" ")
            temp = temp.next
           
    def Nth_Node(self,node,count, N):
        try:
        
            if self.head is None:
                return 0

            if count == N-1:
                return print(node.data)

            else:
                return self.Nth_Node(node.next , count+1, N)
        except:
            return print("Invalid argument given")
        
    def Nth_Node_rec(self,N):
        count = 0
        return self.Nth_Node(self.head, count, N)
    
    
                
if __name__ == '__main__' :
    ListL  = Linked_List()

    ListL.head = Node(1)
    second = Node(2)
    third = Node(3)
    
    ListL.head.next = second
    second.next = third
    
    print("Original List : ")
    ListL.printer_LL()
    print("\n")
    ListL.Push(44)
    ListL.Push(23)
    ListL.Push(14)
    ListL.Push(44)
    print("After Pushing elements : ")
    ListL.printer_LL()
    print("\n")
    ListL.Nth_Node_rec(4)

# %% [markdown]
# #### Program for n’th node from the end of a Linked List

# %% [raw]
# There are two ways to solve the question. First is printing the nth element with formula length -n + 1, this will give nth element from the last. Second approach is to use two pointer technique.

# %% [markdown]
# ###### First Method - Recursive

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
class Linked_List:

    def __init__(self):
        self.head = None
        
    def Push(self, new_data):
        
        new_node = Node(new_data)
        new_node.next = self.head
        self.head = new_node

    def printer_LL(self):
        temp = self.head
        
        while(temp):
            print(temp.data, end=" ")
            temp = temp.next
           
        
    def printNthFromLast(self, n):
      
        temp = self.head
        length = 0
        while temp is not None:
            temp = temp.next
            length += 1
            
        if n>length:
            return print("Node N cant be found to the given Linked List")
        
        temp = self.head
        for j in range(length-n):
            temp = temp.next
        return print("The {} element form the last is : {}".format(n,temp.data))
                
if __name__ == '__main__' :
    ListL  = Linked_List()

    ListL.head = Node(1)
    second = Node(2)
    third = Node(3)
    
    ListL.head.next = second
    second.next = third
    
    print("Original List : ")
    ListL.printer_LL()
    print("\n")
    ListL.Push(4432)
    ListL.Push(2233)
    ListL.Push(1434)
    ListL.Push(4232)
    ListL.Push(1445)
    ListL.Push(4324)
    ListL.Push(1430)
    ListL.Push(4222)
    print("After Pushing elements : ")
    ListL.printer_LL()
    print("\n")
    ListL.printNthFromLast(9)

# %% [markdown]
# ###### Method 2 - Two pointer method

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
class Linked_List:

    def __init__(self):
        self.head = None
        
    def Push(self, new_data):
        
        new_node = Node(new_data)
        new_node.next = self.head
        self.head = new_node

    def printer_LL(self):
        temp = self.head
        
        while(temp):
            print(temp.data, end=" ")
            temp = temp.next
           
        
    def print_Nth_Last_2p(self, n):
        main_ptr = self.head
        ref_ptr  = self.head
        count = 0
        
        if ref_ptr is not None:
            while count < n:
                
                if ref_ptr is None:
                    print("The given node value can't be found, correct the value")
                    return
                
                ref_ptr = ref_ptr.next
                count += 1
                
        if main_ptr is not None:
            while ref_ptr is not None:
                ref_ptr = ref_ptr.next
                main_ptr = main_ptr.next
                
            print(main_ptr.data)
                
                
if __name__ == '__main__' :
    ListL  = Linked_List()

    ListL.head = Node(1)
    second = Node(2)
    third = Node(3)
    
    ListL.head.next = second
    second.next = third
    
    print("Original List : ")
    ListL.printer_LL()
    print("\n")
    ListL.Push(4432)
    ListL.Push(2233)
    ListL.Push(1434)
    ListL.Push(4232)
    ListL.Push(1445)
    ListL.Push(4324)
    ListL.Push(1430)
    ListL.Push(4222)
    print("After Pushing elements : ")
    ListL.printer_LL()
    print("\n")
    ListL.print_Nth_Last_2p(9)

# %% [markdown]
# #### Find the middle of a given linked list

# %% [raw]
# Here also we have 2 methods to solve this. first one is to traverse the array and find length, then again traverse the array till length/2 and find the answer.    The second method is to use two pointers, where first pointer will increase by one point and the second will increase by 2 points. this way  when the second pointerreaches to end, the first will reach to the mid point, and then we can print the value.

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
class Linked_List:

    def __init__(self):
        self.head = None
        
    def Push(self, new_data):
        
        new_node = Node(new_data)
        new_node.next = self.head
        self.head = new_node

    def printer_LL(self):
        temp = self.head
        
        while(temp):
            print(temp.data, end=" ")
            temp = temp.next
           
        
    def print_mid_2p(self):
        fast = self.head
        slow  = self.head
        
        while fast and fast.next:
            slow = slow.next
            fast = fast.next.next
                
        print(slow.data)
                
                
if __name__ == '__main__' :
    ListL  = Linked_List()

    ListL.head = Node(1)
    second = Node(2)
    third = Node(3)
    
    ListL.head.next = second
    second.next = third
    
    print("Original List : ")
    ListL.printer_LL()
    print("\n")
    ListL.Push(4432)
    ListL.Push(2233)
    ListL.Push(1434)
    ListL.Push(4232)
    ListL.Push(1445)
    ListL.Push(4324)
    ListL.Push(1430)
    ListL.Push(4222)
    ListL.Push(33)
    ListL.Push(22222)
    ListL.Push(22)
    print("After Pushing elements : ")
    ListL.printer_LL()
    print("\n")
    ListL.print_mid_2p()

# %% [markdown]
# #### Write a function that counts the number of times a given int occurs in a Linked List

# %% [raw]
# there are also two methods, iterative or recursive. we will look only the recursive one here.

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
class Linked_List:

    def __init__(self):
        self.head = None
        
    def Push(self, new_data):
        
        new_node = Node(new_data)
        new_node.next = self.head
        self.head = new_node

    def printer_LL(self):
        temp = self.head
        
        while(temp):
            print(temp.data, end=" ")
            temp = temp.next
           
    def Counter(self, node ,count , val):
        
        if node is None:
            return print(count)
        
        if node.data == val:
            count += 1
        
        self.Counter(node.next ,count, val)
    
    def Counter_rec(self, val):
        return self.Counter(self.head ,0, val)
    
    

            
if __name__ == '__main__' :
    ListL  = Linked_List()

    ListL.head = Node(1)
    second = Node(2)
    third = Node(3)
    
    ListL.head.next = second
    second.next = third
    
    print("Original List : ")
    ListL.printer_LL()
    print("\n")
    ListL.Push(14)
    ListL.Push(44)
    ListL.Push(23)
    ListL.Push(14)
    ListL.Push(44)
    ListL.Push(14)
    ListL.Push(18)
    ListL.Push(14)
    print("After Pushing elements : ")
    ListL.printer_LL()
    print("\n")
    ListL.Counter_rec(14)
# Out:
# Original List :
# 1 2 3
#
# After Pushing elements :
# 14 18 14 44 14 23 44 14 1 2 3
#
# 4

# %% [markdown]
# #### Detect loop in a linked list

# %% [markdown]
# ref  :https://media.geeksforgeeks.org/wp-content/cdn-uploads/20190621160855/Detect-loop-in-a-linked-list.png

# %% [raw]
# Solution 3: Floyd’s Cycle-Finding Algorithm
#
# Approach: This is the fastest method and has been described below:
#
# Traverse linked list using two pointers.
# Move one pointer(slow_p) by one and another pointer(fast_p) by two.
# If these pointers meet at the same node then there is a loop. If pointers do not meet then linked list doesn’t have a loop.

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
class Linked_List:

    def __init__(self):
        self.head = None
        
    def Push(self, new_data):
        
        new_node = Node(new_data)
        new_node.next = self.head
        self.head = new_node

    def printer_LL(self):
        temp = self.head
        
        while(temp):
            print(temp.data, end=" ")
            temp = temp.next
           
        
    def LL_Loop(self):
        fast_p = self.head
        slow_p  = self.head
        
        while slow_p and fast_p and fast_p.next:
            slow_p = slow_p.next
            fast_p = fast_p.next.next

            if slow_p == fast_p:
                return True
                
                
if __name__ == '__main__' :
    LinList  = Linked_List()
    
    LinList.Push(20)
    LinList.Push(4)
    LinList.Push(15)
    LinList.Push(10)
    print("After Pushing elements : ")
    LinList.printer_LL()
    print("\n")
    
    #We are creating a loop for the testing....
    LinList.head.next.next.next.next = LinList.head
    
    if LinList.LL_Loop():
        print("Yes there is a loop in the linked list")
    else:
        print("No loop found in the given linked list")
# Out:
# After Pushing elements :
# 10 15 4 20
#
# Yes there is a loop in the linked list

# %% [markdown]
# #### Find length of loop in linked list

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
class Linked_List:

    def __init__(self):
        self.head = None
        
    def Push(self, new_data):
        
        new_node = Node(new_data)
        new_node.next = self.head
        self.head = new_node

    def printer_LL(self):
        temp = self.head
        
        while(temp):
            print(temp.data, end=" ")
            temp = temp.next
           
        
    def LL_Loop(self):
        fast_p = self.head
        slow_p  = self.head
        
        while slow_p and fast_p and fast_p.next:
            slow_p = slow_p.next
            fast_p = fast_p.next.next

            if slow_p == fast_p:
                counter = 0
                while slow_p and fast_p and fast_p.next:
                    slow_p = slow_p.next
                    fast_p = fast_p.next.next
                    counter += 1
                    
                    if slow_p == fast_p:
                        return print("lengh of the loop is  : ",counter)
                
                
if __name__ == '__main__' :
    LinList  = Linked_List()
    
    LinList.Push(20)
    LinList.Push(4)
    LinList.Push(15)
    LinList.Push(10)
    LinList.Push(11)
    LinList.Push(12)
    LinList.Push(13)
    print("After Pushing elements : ")
    LinList.printer_LL()
    print("\n")
    
    #We are creating a loop for the testing....
    LinList.head.next.next.next.next.next = LinList.head
    
    LinList.LL_Loop()
# Out:
# After Pushing elements :
# 13 12 11 10 15 4 20
#
# lengh of the loop is  :  5

# %% [markdown]
# #### Function to check if a singly linked list is palindrome

# %%
head = None
left = None
 
class Node:
    def __init__(self, val):
        self.data = val
        self.next = None
        
def isPalindromeUtil(right):
    global head, left
    left = head

    if (right == None):
        return True

    isp = isPalindromeUtil(right.next)
    if (isp == False):
        return False

    isp1 = (right.data == left.data)
    left = left.next
    return isp1

def isPalindrome(head):
    result = isPalindromeUtil(head)
    return result

def push(new_data):
    global head

    new_node = Node(new_data)
    new_node.next = head
    head = new_node

def printList(ptr):
    while (ptr != None):
        print(ptr.data, end="->")
        ptr = ptr.next
 
    print("Null ")

str = ['a', 'd', 'a', 'c', 'a', 'b', 'a']
 
for i in range(0, 7):
    push(str[i])
    printList(head)
 
    if (isPalindrome(head) and i != 0):
        print("Is Palindrome\n")
    else:
        print("Not Palindrome\n")
# Out:
# a->Null
# Not Palindrome
#
# d->a->Null
# Not Palindrome
#
# a->d->a->Null
# Is Palindrome
#
# c->a->d->a->Null
# Not Palindrome
#
# a->c->a->d->a->Null
# Not Palindrome
#
# b->a->c->a->d->a->Null
# Not Palindrome
#
# a->b->a->c->a->d->a->Null
# Not Palindrome

# %% [markdown]
# #### Remove duplicates from a SORTED linked list

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
class Linked_List:

    def __init__(self):
        self.head = None
        
    def Push(self, new_data):
        
        new_node = Node(new_data)
        new_node.next = self.head
        self.head = new_node

    def del_val(self, key):
        temp = self.head
    
        if (temp is not None):
            if (temp.data == key):
                self.head = temp.next
                temp = None
                return

        while (temp is not None):            
            if temp.data == key:
                break
        
            elem = temp
            temp = temp.next
                
        if temp == None:
            return
        
        elem.next = temp.next
        temp = None
        
        
    def printer_LL(self):
        temp = self.head
        while(temp):
            print(temp.data, end=" ")
            temp = temp.next
        
    def Rem_Duplicates(self):
        
        elem = self.head
        
        while elem.next is not None:
            if (elem.data == elem.next.data):
                    noder = elem.next.next
                    elem.next = None
                    elem.next = noder
            else:   
                elem = elem.next
                
        return self.head
    
    
if __name__ == '__main__' :
    LinList  = Linked_List()
    
    LinList.Push(20)
    LinList.Push(20)
    LinList.Push(15)
    LinList.Push(10)
    LinList.Push(11)
    LinList.Push(11)
    LinList.Push(11)
    LinList.Push(14)
    LinList.Push(14)
    LinList.Push(15)
    print("After Pushing elements : ")
    LinList.printer_LL()
    print("\n")
    
    LinList.Rem_Duplicates()
    LinList.printer_LL()
# Out:
# After Pushing elements :
# 15 14 14 11 11 11 10 15 20 20
#
# 15 14 11 10 15 20

# %% [markdown]
# #### Remove duplicates from an unsorted linked list

# %% [raw]
# we can do it using two loops or sorting it and then solving it. second one we've seen above, so now we will see,how to remove duplicates using two loops.

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
class Linked_List:

    def __init__(self):
        self.head = None
        
    def Push(self, new_data):
        
        new_node = Node(new_data)
        new_node.next = self.head
        self.head = new_node

    
    def printer_LL(self):
        temp = self.head
        while(temp):
            print(temp.data, end=" ")
            temp = temp.next
        
    def Rem_Duplicates(self):
        
        elem = self.head
        
        while elem.next is not None:
            if (elem.data == elem.next.data):
                    noder = elem.next.next
                    elem.next = None
                    elem.next = noder
            else:   
                elem = elem.next
                
        return self.head
    
    
if __name__ == '__main__' :
    LinList  = Linked_List()
    
    LinList.Push(20)
    LinList.Push(20)
    LinList.Push(15)
    LinList.Push(10)
    LinList.Push(11)
    LinList.Push(11)
    LinList.Push(11)
    LinList.Push(14)
    LinList.Push(14)
    LinList.Push(15)
    print("After Pushing elements : ")
    LinList.printer_LL()
    print("\n")
    
    LinList.Rem_Duplicates()
    LinList.printer_LL()
# Out:
# After Pushing elements :
# 15 14 14 11 11 11 10 15 20 20
#
# 15 14 11 10 15 20

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
class Linked_List:

    def __init__(self):
        self.head = None
        
    def Push(self, new_data):
        
        new_node = Node(new_data)
        new_node.next = self.head
        self.head = new_node

    
    def printer_LL(self):
        temp = self.head
        while(temp):
            print(temp.data, end=" ")
            temp = temp.next
        
    def Rem_unsort_dup(self):
        
        temp = self.head
        
        while ((temp != None) and (temp.next != None)):
            bamp = temp
            while bamp.next is not None:
                
                if temp.data == bamp.next.data:
                    noder = bamp.next
                    bamp.next = noder.next
                else:
                    bamp = bamp.next
                    
            temp = temp.next
    

if __name__ == '__main__' :
    LinList  = Linked_List()
    
    LinList.Push(12)
    LinList.Push(20)
    LinList.Push(15)
    LinList.Push(10)
    LinList.Push(11)
    LinList.Push(20)
    LinList.Push(11)
    LinList.Push(14)
    LinList.Push(10)
    LinList.Push(15)
    print("After Pushing elements : ")
    LinList.printer_LL()
    print("\n")
    
    LinList.Rem_unsort_dup()
    LinList.printer_LL()
# Out:
# After Pushing elements :
# 15 10 14 11 20 11 10 15 20 12
#
# 15 10 14 11 20 12

# %% [markdown]
# #### Swap nodes in a linked list without swapping data

# %% [raw]
# This may look a simple problem, but is an interesting question as it has the following cases to be handled.
#
# x and y may or may not be adjacent.
# Either x or y may be a head node.
# Either x or y may be the last node.
# x and/or y may not be present in the linked list.

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
class Linked_List:

    def __init__(self):
        self.head = None
        
    def Push(self, new_data):
        
        new_node = Node(new_data)
        new_node.next = self.head
        self.head = new_node

    
    def printer_LL(self):
        temp = self.head
        while(temp):
            print(temp.data, end=" ")
            temp = temp.next
        
    def Node_Swapper(self, x, y):
        
        prevX = None
        currX = self.head
        
        while currX != None and currX.data != x : 
            prevX = currX
            currX = currX.next
            
            
        prevY = None
        currY = self.head
        
        while currY != None and currY.data != y : 
            prevY = currY
            currY = currY.next
            
        
        if currX == None or currY == None:
            return 
        
        if prevX != None:
            prevX.next = currY
        else:
            self.head = currY
            
        
        if prevY != None:
            prevY.next = currX
        else:
            self.head = currX
            
        
        currX.next , currY.next = currY.next , currX.next
        

if __name__ == '__main__' :
    LinList  = Linked_List()
    
    LinList.Push(12)
    LinList.Push(10)
    LinList.Push(20)
    LinList.Push(11)
    LinList.Push(14)
    LinList.Push(15)
    print("After Pushing elements : ")
    LinList.printer_LL()
    print("\n")

    LinList.Node_Swapper(14,12)
    LinList.printer_LL()
# Out:
# After Pushing elements :
# 15 14 11 20 10 12
#
# 15 12 11 20 10 14

# %% [markdown]
# #### Pairwise swap elements of a given linked list

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
class Linked_List:

    def __init__(self):
        self.head = None
        
    def Push(self, new_data):
        
        new_node = Node(new_data)
        new_node.next = self.head
        self.head = new_node

    
    def printer_LL(self):
        temp = self.head
        while(temp):
            print(temp.data, end=" ")
            temp = temp.next
        
    def Node_Swap_pair_rec(self, node):

        if node == None or node.next == None:
            return 
        
        node.data , node.next.data = node.next.data , node.data
        
        self.Node_Swap_pair_rec(node.next.next)
        
    def Pair_node_swap_rec(self):
        
        return self.Node_Swap_pair_rec(self.head)

if __name__ == '__main__' :
    LinList  = Linked_List()
    
    LinList.Push(12)
    LinList.Push(10)
    LinList.Push(20)
    LinList.Push(11)
    LinList.Push(14)
    LinList.Push(15)
    LinList.Push(28)
    print("The original Linked List: ")
    LinList.printer_LL()
    print("\n")

    LinList.Pair_node_swap_rec()
    print("After Swapping pair elements : ")
    LinList.printer_LL()
# Out:
# The original Linked List:
# 28 15 14 11 20 10 12
#
# After Swapping pair elements :
# 15 28 11 14 10 20 12

# %% [markdown]
# #### Move last element to front of a given Linked List

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
class Linked_List:

    def __init__(self):
        self.head = None
        
    def Push(self, new_data):
        
        new_node = Node(new_data)
        new_node.next = self.head
        self.head = new_node

    
    def printer_LL(self):
        temp = self.head
        while(temp):
            print(temp.data, end=" ")
            temp = temp.next
        
    def last_to_first(self):
        
        temp = self.head
        prev = None
        while temp.next != None:
            prev = temp
            temp = temp.next
        
        prev.next = None
        temp.next = self.head
        self.head = temp

if __name__ == '__main__' :
    LinList  = Linked_List()
    
    LinList.Push(12)
    LinList.Push(10)
    LinList.Push(20)
    LinList.Push(11)
    LinList.Push(14)
    LinList.Push(15)
    LinList.Push(28)
    print("The original Linked List: ")
    LinList.printer_LL()
    print("\n")

    LinList.last_to_first()
    print("After moving last element to front : ")
    LinList.printer_LL()
# Out:
# The original Linked List:
# 28 15 14 11 20 10 12
#
# After moving last element to front :
# 12 28 15 14 11 20 10

# %% [markdown]
# #### Intersection of two Sorted Linked Lists

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
class Linked_List:

    def __init__(self):
        self.head = None
        
    def Push(self, new_data):
        
        new_node = Node(new_data)
        new_node.next = self.head
        self.head = new_node

    
    def printer_LL(self):
        temp = self.head
        while(temp):
            print(temp.data, end=" ")
            temp = temp.next
        
    def InterSection_AB(self,A,B):
        tempA = A.head
        tempB = B.head
        
        while tempA is not None and tempB is not None:
            
            if (tempA.data == tempB.data) :
                print(tempA.data, end = " ")
                tempA = tempA.next
                tempB = tempB.next
            
            elif (tempA.data < tempB.data):
                tempA = tempA.next
            else:
                tempB = tempB.next        
    
if __name__ == '__main__' :
    ListA  = Linked_List()
    ListB  = Linked_List()
    Result = None
    
    ListA.Push(22)
    ListA.Push(20)
    ListA.Push(18)
    ListA.Push(16)
    ListA.Push(14)
    ListA.Push(12)
    ListA.Push(10)
    
    ListB.Push(17)
    ListB.Push(16)
    ListB.Push(15)
    ListB.Push(14)
    ListB.Push(13)
    ListB.Push(12)
    
    ListA.InterSection_AB(ListA, ListB)
# Out:
# 12 14 16

# %% [markdown]
# #### Write a function to get the intersection point of two Linked Lists

# %% [markdown]
# https://www.geeksforgeeks.org/wp-content/uploads/2009/10/Y-ShapedLinked-List.gif

# %% [markdown]
# ###### Method 3(Using difference of node counts)
#
# Get count of the nodes in the first list, let count be c1.
# Get count of the nodes in the second list, let count be c2.
# Get the difference of counts d = abs(c1 – c2)
# Now traverse the bigger list from the first node till d nodes so that from here onwards both the lists have equal no of nodes
# Then we can traverse both the lists in parallel till we come across a common node. (Note that getting a common node is done by comparing the address of the nodes)

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
class Linked_List:

    def __init__(self):
        self.head = None
        
    def Push(self, new_data):
        
        new_node = Node(new_data)
        new_node.next = self.head
        self.head = new_node

    
    def printer_LL(self):
        temp = self.head
        while(temp):
            print(temp.data, end=" ")
            temp = temp.next
            
        
    def intersect_pt(self,A ,B):
        
        temp = A.head
        lenA = 0
        while temp is not None:
            lenA += 1
            temp = temp.next
        
        temp = B.head
        lenB = 0
        while temp is not None:
            lenB += 1
            temp = temp.next
            
        d = abs(lenA - lenB)
        
        
        if lenA > lenB:
            curr1 = A.head
            curr2 = B.head
        else:
            curr1 = B.head
            curr2 = A.head
            
            
        for i in range(d):
            if curr1 is None:
                return -1
            curr1 = curr1.next
        
        while curr1 is not None and curr2 is not None:
            if curr1 == curr2:
                return print("Intersection point of the lists is : ", curr1.data, "at address", curr1)
            curr1 = curr1.next
            curr2 = curr2.next
        
        return -1
        
if __name__ == '__main__' :
    ListA  = Linked_List()
    ListB  = Linked_List()
    Result = None
    
    ListA.Push(3)
    ListA.Push(15)
    ListA.Push(30)
    
    ListB.Push(6)
    ListB.Push(9)
    ListB.Push(15)
    ListB.Push(25)
    ListB.Push(30)
    
    ListA.head.next = ListB.head.next.next
    
    ListA.intersect_pt(ListA ,ListB)
# Out:
# Intersection point of the lists is :  15 at address <__main__.Node object at 0x000002F6DBE51340>

# %% [markdown]
# #### QuickSort on Singly Linked List

# %%
class Node:
    def __init__(self, val):
        self.data = val
        self.next = None

class QuickSortLinkedList:
 
    def __init__(self):
        self.head=None
 
    def addNode(self,data):
        if (self.head == None):
            self.head = Node(data)
            return
 
        curr = self.head
        while (curr.next != None):
            curr = curr.next
 
        newNode = Node(data)
        curr.next = newNode
 
    def printList(self,n):
        while (n != None):
            print(n.data, end=" ")
            n = n.next

    def paritionLast(self,start, end):
        if (start == end or start == None or end == None):
            return start
 
        pivot_prev = start
        curr = start
        pivot = end.data
 
        while (start != end):
            if (start.data < pivot):
               
                pivot_prev = curr
                temp = curr.data
                curr.data = start.data
                start.data = temp
                curr = curr.next
            start = start.next
 
        temp = curr.data
        curr.data = pivot
        end.data = temp

        return pivot_prev
 
    def sort(self, start, end):
        if(start == None or start == end or start == end.next):
            return
        
        pivot_prev = self.paritionLast(start, end)
        self.sort(start, pivot_prev)

        if(pivot_prev != None and pivot_prev == start):
            self.sort(pivot_prev.next, end)

        elif (pivot_prev != None and pivot_prev.next != None):
            self.sort(pivot_prev.next.next, end)
            
            
if __name__ == "__main__":
    ll = QuickSortLinkedList()
    ll.addNode(30)
    ll.addNode(3)
    ll.addNode(4)
    ll.addNode(20)
    ll.addNode(5)
 
    n = ll.head
    while (n.next != None):
        n = n.next
 
    print("\nLinked List before sorting")
    ll.printList(ll.head)
 
    ll.sort(ll.head, n)
 
    print("\nLinked List after sorting");
    ll.printList(ll.head)
# Out:
# Linked List before sorting
# 30 3 4 20 5
# Linked List after sorting
# 3 4 5 20 30

# %% [markdown]
# #### Segregate even and odd nodes in a Linked List

# %% [raw]
# Method 1
# The idea is to get pointer to the last node of list. And then traverse the list starting from the head node and move the odd valued nodes from their current position to end of the list.
# Thanks to blunderboy for suggesting this method.
# Algorithm:
# …1) Get pointer to the last node.
# …2) Move all the odd nodes to the end.
# ……..a) Consider all odd nodes before the first even node and move them to end.
# ……..b) Change the head pointer to point to the first even node.
# ……..b) Consider all odd nodes after the first even node and move them to the end

# %% [raw]
# Method 2
# The idea is to split the linked list into two: one containing all even nodes and other containing all odd nodes. And finally, attach the odd node linked list after the even node linked list.
# To split the Linked List, traverse the original Linked List and move all odd nodes to a separate Linked List of all odd nodes. At the end of loop, the original list will have all the even nodes and the odd node list will have all the odd nodes. To keep the ordering of all nodes same, we must insert all the odd nodes at the end of the odd node list. And to do that in constant time, we must keep track of last pointer in the odd node list.

# %%
#// --------------------------- Here are discussing method 2 -----------------------//

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
class Linked_List:

    def __init__(self):
        self.head = None
        
    def Push(self, new_data):
        
        new_node = Node(new_data)
        new_node.next = self.head
        self.head = new_node

    
    def printer_LL(self):
        temp = self.head
        while(temp):
            print(temp.data, end=" ")
            temp = temp.next
            
    def Segregator_OddEven(self):
        currNode = self.head
        
        Estart = None
        Eend = None
        
        Ostart = None
        Oend = None
        
        while currNode is not None:
            val = currNode.data
            
            if (int(val)%2 == 0):
                
                if Estart == None:
                    Estart = currNode
                    Eend = Estart
                    
                else:
                    Eend.next = currNode
                    Eend = Eend.next
                    
            else:
                
                if Ostart == None:
                    Ostart = currNode
                    Oend = Ostart
                else:
                    Oend.next = currNode
                    Oend = Oend.next
                    
            currNode = currNode.next
        
        if Estart == None and Ostart  == None:
            return -1
        
        Eend.next = Ostart
        Oend.next = None
        
        head = Estart
        
if __name__ == '__main__' :
    ListA  = Linked_List()

    ListA.Push(6)
    ListA.Push(9)
    ListA.Push(15)
    ListA.Push(25)
    ListA.Push(30)
    
    ListA.Segregator_OddEven()
    
    ListA.printer_LL()
# Out:
# 30 6 25 15 9

# %% [markdown]
# #### Reverse a linked list

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
class Linked_List:

    def __init__(self):
        self.head = None
        
    def Push(self, new_data):
        
        new_node = Node(new_data)
        new_node.next = self.head
        self.head = new_node

    
    def printer_LL(self):
        temp = self.head
        while(temp):
            print(temp.data, end=" ")
            temp = temp.next
    
    def Reverse_LL(self):
        prev = None
        current = self.head
        while(current is not None):
            add = current.next
            current.next = prev
            prev = current
            current = add
        self.head = prev
        
if __name__ == '__main__' :
    ListL  = Linked_List()

    ListL.Push(6)
    ListL.Push(9)
    ListL.Push(15)
    ListL.Push(25)
    ListL.Push(30)
    
    ListL.Reverse_LL()
    ListL.printer_LL()
# Out:
# 6 9 15 25 30

# %% [markdown]
# #### Merge Sort a  single linked list

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
class Linked_List:

    def __init__(self):
        self.head = None
        
    def Push(self, new_data):
        
        new_node = Node(new_data)
        new_node.next = self.head
        self.head = new_node

    
    def printer_LL(self):
        temp = self.head
        while(temp):
            print(temp.data, end=" ")
            temp = temp.next
            
    def getMiddle(self,head):      #Function to get the middle element every time
        
        if head is None:
            return head
        
        slow = head
        fast = head
        
        while fast.next != None and fast.next.next != None:
            slow = slow.next
            fast = fast.next.next
        
        return slow
    
    def sortedMerge(self,a,b):
        result = None
        
        if a == None: 
            return b
        if b == None:
            return a
        
        if a.data <= b.data:
            result = a
            result.next = self.sortedMerge(a.next , b)
        else:
            result = b
            result.next = self.sortedMerge(a, b.next)
        
        return result

    
    def MergeSort(self , h):
        
        if h == None or h.next == None:
            return h
        
        middle = self.getMiddle(h)
        nexttomiddle = middle.next
        
        #Setting middle.next as None to break the list at this point
        middle.next = None
        
        #merge sort both seperated lists
        left = self.MergeSort(h)
        right = self.MergeSort(nexttomiddle)
        
        ans = self.sortedMerge(left,right)
        
        return ans
        
        
if __name__ == '__main__' :
    ListL  = Linked_List()
    
    ListL.Push(15)
    ListL.Push(10)
    ListL.Push(5)
    ListL.Push(20)
    ListL.Push(3)
    ListL.Push(2)
    
    ListL.MergeSort(ListL.head)
    ListL.printer_LL()
# Out:
# 2 3 5 10 15 20
